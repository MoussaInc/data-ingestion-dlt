# %%
import dlt
from itertools import islice
from dlt.sources.rest_api import rest_api_source

import duckdb

# %% [markdown]
# ## 🔗 Step 2: Define the API Source (Open Library)

# %%
def openlibrary_source(query: str = "harry potter"):

    return rest_api_source({
        "client": {
            "base_url": "https://openlibrary.org",
        },
        "resource_defaults": {
            "primary_key": "key",
            "write_disposition": "replace",
        },
        "resources": [
            {
                "name": "books",
                "endpoint": {
                    "path": "search.json",
                    "params": {
                        "q": query,
                        "limit": 100,
                    },
                    "data_selector": "docs",
                    "paginator": {
                        "type": "offset",
                        "limit": 100,
                        "offset_param": "offset",
                        "limit_param": "limit",
                        "total_path": "numFound",
                    },
                },
            },
        ],
    })

# %% [markdown]
# ## 🔧 Step 3: Create the dlt Pipeline

# %%
pipeline = dlt.pipeline(
    pipeline_name="open_library",
    destination="duckdb",       # le type de destination
    dataset_name="library",
    progress="log",
    dev_mode=False           # si tu veux réécrire tout
)

# %%
extract_info = pipeline.extract(openlibrary_source())
# Out:
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 139.80 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 1.15s | Rate: 0.00/s
# books: 100  | Time: 0.00s | Rate: 5115004.88/s
# Memory usage: 141.48 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 2.29s | Rate: 0.00/s
# books: 400  | Time: 1.13s | Rate: 352.94/s
# Memory usage: 142.54 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 3.41s | Rate: 0.00/s
# books: 600  | Time: 2.26s | Rate: 265.83/s
# Memory usage: 144.27 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 4.50s | Rate: 0.00/s
# books: 900  | Time: 3.34s | Rate: 269.11/s
# Memory usage: 144.85 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 6.06s | Rate: 0.00/s
# books: 1200  | Time: 4.91s | Rate: 244.57/s
# Memory usage: 145.73 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 7.29s | Rate: 0.00/s
# books: 1400  | Time: 6.14s | Rate: 228.11/s
# Memory usage: 146.20 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 8.42s | Rate: 0.00/s
# books: 1600  | Time: 7.26s | Rate: 220.30/s
# Memory usage: 146.84 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 9.73s | Rate: 0.00/s
# books: 1800  | Time: 8.58s | Rate: 209.82/s
# Memory usage: 147.49 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 15.28s | Rate: 0.00/s
# books: 2000  | Time: 14.12s | Rate: 141.60/s
# Memory usage: 148.07 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 16.37s | Rate: 0.00/s
# books: 2200  | Time: 15.21s | Rate: 144.60/s
# Memory usage: 148.19 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 17.43s | Rate: 0.00/s
# books: 2400  | Time: 16.27s | Rate: 147.48/s
# Memory usage: 148.19 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 18.86s | Rate: 0.00/s
# books: 2600  | Time: 17.71s | Rate: 146.81/s
# Memory usage: 148.20 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 20.09s | Rate: 0.00/s
# books: 2800  | Time: 18.94s | Rate: 147.86/s
# Memory usage: 148.23 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 21.63s | Rate: 0.00/s
# books: 3000  | Time: 20.47s | Rate: 146.54/s
# Memory usage: 148.24 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 22.65s | Rate: 0.00/s
# books: 3200  | Time: 21.50s | Rate: 148.86/s
# Memory usage: 148.43 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 23.78s | Rate: 0.00/s
# books: 3400  | Time: 22.62s | Rate: 150.29/s
# Memory usage: 148.88 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 24.91s | Rate: 0.00/s
# books: 3600  | Time: 23.75s | Rate: 151.55/s
# Memory usage: 149.50 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 25.93s | Rate: 0.00/s
# books: 3768  | Time: 24.78s | Rate: 152.07/s
# Memory usage: 150.04 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 1/1 (100.0%) | Time: 26.06s | Rate: 0.04/s
# books: 3768  | Time: 24.91s | Rate: 151.29/s
# Memory usage: 150.50 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 150.50 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# _dlt_pipeline_state: 1  | Time: 0.00s | Rate: 182361.04/s
# Memory usage: 150.50 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 1/1 (100.0%) | Time: 0.02s | Rate: 58.59/s
# _dlt_pipeline_state: 1  | Time: 0.01s | Rate: 78.22/s
# Memory usage: 150.50 MB (32.00%) | CPU usage: 0.00%

# %% [markdown]
# ## ⬇️ Step 4: Extract
#
# Extract means:
# - dlt sends requests to the Open Library API
# - the raw JSON responses are downloaded
# - the results are stored in dlt’s local working folder
#
# At this stage, the data is **not** in DuckDB yet. We are just confirming that we successfully pulled data from the API.

# %%
extract_info = pipeline.extract(openlibrary_source())
# Out:
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 151.59 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.84s | Rate: 0.00/s
# books: 100  | Time: 0.00s | Rate: 9754195.35/s
# Memory usage: 151.60 MB (32.00%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 2.21s | Rate: 0.00/s
# books: 400  | Time: 1.37s | Rate: 292.40/s
# Memory usage: 151.64 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 3.52s | Rate: 0.00/s
# books: 700  | Time: 2.68s | Rate: 261.40/s
# Memory usage: 151.78 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 4.76s | Rate: 0.00/s
# books: 1000  | Time: 3.92s | Rate: 255.12/s
# Memory usage: 151.95 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 6.10s | Rate: 0.00/s
# books: 1300  | Time: 5.26s | Rate: 247.17/s
# Memory usage: 151.95 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 7.29s | Rate: 0.00/s
# books: 1600  | Time: 6.45s | Rate: 247.91/s
# Memory usage: 151.95 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 8.56s | Rate: 0.00/s
# books: 1900  | Time: 7.72s | Rate: 246.16/s
# Memory usage: 151.95 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 10.09s | Rate: 0.00/s
# books: 2200  | Time: 9.25s | Rate: 237.75/s
# Memory usage: 151.95 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 11.37s | Rate: 0.00/s
# books: 2500  | Time: 10.53s | Rate: 237.47/s
# Memory usage: 151.96 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 12.45s | Rate: 0.00/s
# books: 2700  | Time: 11.61s | Rate: 232.57/s
# Memory usage: 151.96 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 13.67s | Rate: 0.00/s
# books: 3000  | Time: 12.84s | Rate: 233.71/s
# Memory usage: 151.96 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 14.99s | Rate: 0.00/s
# books: 3400  | Time: 14.15s | Rate: 240.29/s
# Memory usage: 152.23 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 16.00s | Rate: 0.00/s
# books: 3600  | Time: 15.16s | Rate: 237.41/s
# Memory usage: 152.77 MB (31.90%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 1/1 (100.0%) | Time: 17.00s | Rate: 0.06/s
# books: 3768  | Time: 16.16s | Rate: 233.10/s
# Memory usage: 154.21 MB (31.90%) | CPU usage: 0.00%

# %%
load_id = extract_info.loads_ids[-1]
m = extract_info.metrics[load_id][0]

print("Resources:", list(m["resource_metrics"].keys()))
print("Tables:", list(m["table_metrics"].keys()))
print("Load ID:", load_id)
print()

for resource, rm in m["resource_metrics"].items():
    print(f"Resource: {resource}")
    print(f"rows extracted: {rm.items_count}")
    print()
# Out:
# Resources: ['books']
# Tables: ['books']
# Load ID: 1774111991.7967408
#
# Resource: books
# rows extracted: 3768

# %% [markdown]
# ## 🔄 Step 5: Normalize
#
# During normalization, dlt does three key things:
#
# ### 1. Adds Tracking Columns to the Main Table
# dlt adds special columns to every table:
# - `_dlt_id`: A unique identifier for each row
# - `_dlt_load_id`: Links each row to the load job that created it
#
# ### 2. Flattens Nested Data into Child Tables
# dlt flattens these nested structures into separate **child tables** with names like:
# - `books__author_name`
# - `books__author_key`
# - `books__language`
#
# Each child table has a `_dlt_parent_id` column that references `_dlt_id` in the parent table. This is how dlt maintains relationships.
#
# ### 3. Creates Metadata Tables
# dlt also creates internal tables to track pipeline state:
# - `_dlt_loads`: Tracks load history (when data was loaded, status)
# - `_dlt_pipeline_state`: Stores pipeline state for incremental loading
# - `_dlt_version`: Tracks schema versions

# %%
normalize_info = pipeline.normalize()
# Out:
# ------------------- Normalize rest_api in 1774111965.618473 --------------------
# Files: 0/2 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 154.21 MB (31.90%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1774111965.618473 --------------------
# Files: 0/2 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Items: 0  | Time: 0.00s | Rate: 0.00/s
# Memory usage: 154.21 MB (31.90%) | CPU usage: 0.00%
# 2026-03-21 17:53:29,755|[WARNING]|26674|132528765931648|dlt|normalize.py|run:323|When normalizing package 1774111991.7967408 with schema rest_api: the storage schema hash yRMTyxhHSpqNBxmSvs0kxHCqc+V3kD4IaGyTUK9sl9c= is different from extract package schema hash qxF46KdI/zxmxIUii/yjWRxwueSh3Myf+y2Uq3n9J0A=. Storage schema was used.
# ------------------- Normalize rest_api in 1774111965.618473 --------------------
# Files: 13/2 (650.0%) | Time: 0.89s | Rate: 14.53/s
# Items: 26704  | Time: 0.89s | Rate: 29868.40/s
# Memory usage: 157.78 MB (32.00%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1774111991.7967408 -------------------
# Files: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 157.78 MB (32.00%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1774111991.7967408 -------------------
# Files: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Items: 0  | Time: 0.00s | Rate: 0.00/s
# Memory usage: 157.78 MB (32.00%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1774111991.7967408 -------------------
# Files: 12/1 (1200.0%) | Time: 0.71s | Rate: 16.85/s
# Items: 20745  | Time: 0.71s | Rate: 29153.27/s
# Memory usage: 160.07 MB (32.00%) | CPU usage: 0.00%

# %%
load_id = normalize_info.loads_ids[-1]
m = normalize_info.metrics[load_id][0]

print("Load ID:", load_id)
print()

print("Tables created/updated:")
for table_name, tm in m["table_metrics"].items():
    # skip dlt internal tables to keep it beginner-friendly
    if table_name.startswith("_dlt"):
        continue
    print(f"  - {table_name}: {tm.items_count} rows")
# Out:
# Load ID: 1774111991.7967408
#
# Tables created/updated:
#   - books: 3768 rows
#   - books__author_key: 4700 rows
#   - books__author_name: 4700 rows
#   - books__ia: 1833 rows
#   - books__ia_collection: 2103 rows
#   - books__language: 3549 rows
#   - books__series_key: 9 rows
#   - books__series_name: 9 rows
#   - books__series_position: 9 rows
#   - books__id_standard_ebooks: 3 rows
#   - books__id_librivox: 33 rows
#   - books__id_project_gutenberg: 29 rows

# %%
# Display schema 
pipeline.default_schema
# Out:
# <dlt.Schema(name='rest_api', version=2, tables=['_dlt_version', '_dlt_loads', 'books', '_dlt_pipeline_state', 'books__author_key', 'books__author_name', 'books__ia', 'books__ia_collection', 'books__language', 'books__series_key', 'books__series_name', 'books__series_position', 'books__id_standard_ebooks', 'books__id_librivox', 'books__id_project_gutenberg'], version_hash='yRMTyxhHSpqNBxmSvs0kxHCqc+V3kD4IaGyTUK9sl9c=')>

# %% [markdown]
# ## 📤 Step 6:
#
# Load means:
#
#     dlt creates tables in DuckDB (if they do not already exist)
#     the normalized rows are inserted into those tables
#     the pipeline records the load in its internal tracking tables

# %%
load_info = pipeline.load()
# Out:
# ---------------------- Load rest_api in 1774111965.618473 ----------------------
# Jobs: 0/13 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 184.73 MB (32.00%) | CPU usage: 0.00%
#
# ---------------------- Load rest_api in 1774111965.618473 ----------------------
# Jobs: 12/13 (92.3%) | Time: 1.26s | Rate: 9.56/s
# Memory usage: 300.93 MB (32.60%) | CPU usage: 0.00%
#
# ---------------------- Load rest_api in 1774111965.618473 ----------------------
# Jobs: 13/13 (100.0%) | Time: 1.50s | Rate: 8.69/s
# Memory usage: 215.64 MB (32.20%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1774111991.7967408 ----------------------
# Jobs: 0/12 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 215.64 MB (32.20%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1774111991.7967408 ----------------------
# Jobs: 11/12 (91.7%) | Time: 1.26s | Rate: 8.70/s
# Memory usage: 253.70 MB (32.60%) | CPU usage: 0.00%
#
# --------------------- Load rest_api in 1774111991.7967408 ----------------------
# Jobs: 12/12 (100.0%) | Time: 1.49s | Rate: 8.03/s
# Memory usage: 225.75 MB (32.50%) | CPU usage: 0.00%

# %% [markdown]
# ## 🚀 Step 7: Run the Full Pipeline
#
# <p>
#   <code>pipeline.run()</code> simply combines the three steps we already executed manually:
# </p>
# <ol>
#   <li><strong>Extract</strong> – fetch data from the Open Library API</li>
#   <li><strong>Normalize</strong> – convert nested JSON into relational tables</li>
#   <li><strong>Load</strong> – write those tables into DuckDB</li>
# </ol>
# <p>In other words, this:</p>
# <pre><code>pipeline.run(source)</code></pre>
# <p>is equivalent to:</p>
# <pre><code>pipeline.extract(source)
# pipeline.normalize()
# pipeline.load()</code></pre>

# %%
load_info = pipeline.run(openlibrary_source())
# Out:
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 208.31 MB (32.50%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 1.03s | Rate: 0.00/s
# books: 100  | Time: 0.00s | Rate: 9118052.17/s
# Memory usage: 208.34 MB (32.50%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 2.33s | Rate: 0.00/s
# books: 400  | Time: 1.30s | Rate: 307.69/s
# Memory usage: 208.35 MB (32.40%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 3.80s | Rate: 0.00/s
# books: 800  | Time: 2.77s | Rate: 288.69/s
# Memory usage: 208.35 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 4.86s | Rate: 0.00/s
# books: 1100  | Time: 3.83s | Rate: 287.38/s
# Memory usage: 208.35 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 6.36s | Rate: 0.00/s
# books: 1400  | Time: 5.33s | Rate: 262.46/s
# Memory usage: 208.36 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 7.37s | Rate: 0.00/s
# books: 1600  | Time: 6.35s | Rate: 252.13/s
# Memory usage: 208.36 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 8.64s | Rate: 0.00/s
# books: 1900  | Time: 7.61s | Rate: 249.56/s
# Memory usage: 208.36 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 9.94s | Rate: 0.00/s
# books: 2200  | Time: 8.91s | Rate: 246.80/s
# Memory usage: 208.38 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 11.26s | Rate: 0.00/s
# books: 2500  | Time: 10.23s | Rate: 244.42/s
# Memory usage: 208.38 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 12.49s | Rate: 0.00/s
# books: 2800  | Time: 11.47s | Rate: 244.19/s
# Memory usage: 208.39 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 13.68s | Rate: 0.00/s
# books: 3100  | Time: 12.65s | Rate: 245.12/s
# Memory usage: 208.39 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 14.71s | Rate: 0.00/s
# books: 3300  | Time: 13.68s | Rate: 241.15/s
# Memory usage: 208.39 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 15.78s | Rate: 0.00/s
# books: 3500  | Time: 14.75s | Rate: 237.28/s
# Memory usage: 208.39 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 0/1 (0.0%) | Time: 17.32s | Rate: 0.00/s
# books: 3768  | Time: 16.29s | Rate: 231.29/s
# Memory usage: 208.40 MB (32.30%) | CPU usage: 0.00%
#
# ------------------------------- Extract rest_api -------------------------------
# Resources: 1/1 (100.0%) | Time: 17.45s | Rate: 0.06/s
# books: 3768  | Time: 16.42s | Rate: 229.46/s
# Memory usage: 208.81 MB (32.30%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1774112013.971483 --------------------
# Files: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 208.81 MB (32.30%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1774112013.971483 --------------------
# Files: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Items: 0  | Time: 0.00s | Rate: 0.00/s
# Memory usage: 208.81 MB (32.30%) | CPU usage: 0.00%
#
# ------------------- Normalize rest_api in 1774112013.971483 --------------------
# Files: 12/1 (1200.0%) | Time: 0.76s | Rate: 15.85/s
# Items: 20582  | Time: 0.76s | Rate: 27195.52/s
# Memory usage: 211.21 MB (32.30%) | CPU usage: 0.00%
#
# ---------------------- Load rest_api in 1774112013.971483 ----------------------
# Jobs: 0/12 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 211.21 MB (32.30%) | CPU usage: 0.00%
#
# ---------------------- Load rest_api in 1774112013.971483 ----------------------
# Jobs: 11/12 (91.7%) | Time: 1.20s | Rate: 9.16/s
# Memory usage: 291.09 MB (32.70%) | CPU usage: 0.00%
#
# ---------------------- Load rest_api in 1774112013.971483 ----------------------
# Jobs: 12/12 (100.0%) | Time: 1.42s | Rate: 8.42/s
# Memory usage: 222.37 MB (32.40%) | CPU usage: 0.00%

# %% [markdown]
# ## 🔎 Step 8: Inspect the Loaded Data

# %%
# List available tables
ds = pipeline.dataset()
ds.tables
# Out:
# ['books',
#  'books__author_key',
#  'books__author_name',
#  'books__ia',
#  'books__ia_collection',
#  'books__language',
#  'books__series_key',
#  'books__series_name',
#  'books__series_position',
#  'books__id_standard_ebooks',
#  'books__id_librivox',
#  'books__id_project_gutenberg',
#  '_dlt_version',
#  '_dlt_loads',
#  '_dlt_pipeline_state']

# %%
# main table
df = ds.books.df()      
df.head(3)
# Out:
#   cover_edition_key   cover_i   ebook_access  edition_count  \
# 0       OL61027601M  15155833     borrowable            397
# 1       OL26378158M  15158660  printdisabled            144
# 2       OL26234270M  10580435     borrowable            279
#
#    first_publish_year  has_fulltext              key lending_edition_s  \
# 0                1997          True  /works/OL82563W       OL38565767M
# 1                2007          True  /works/OL82586W               NaN
# 2                1999          True  /works/OL82536W       OL48101764M
#
#             lending_identifier_s  public_scan_b  \
# 0  harrypotterylapi0000rowl_q5r6          False
# 1                            NaN          False
# 2                 bdrc-W8LS66814          False
#
#                                       title       _dlt_load_id  \
# 0  Harry Potter and the Philosopher's Stone  1774112013.971483
# 1      Harry Potter and the Deathly Hallows  1774112013.971483
# 2  Harry Potter and the Prisoner of Azkaban  1774112013.971483
#
#           _dlt_id subtitle
# 0  mV8lH3xJSNdo3w      NaN
# 1  flcaIldttqZXPQ      NaN
# 2  +usmF0rfDYs6RA      NaN

# %%
con = duckdb.connect("open_library.duckdb")
books_df = con.execute("SELECT * FROM books LIMIT 10").fetchdf()
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[16], line 2
#       1 con = duckdb.connect("open_library.duckdb")
# ----> 2 books_df = con.execute("SELECT * FROM books LIMIT 10").fetchdf()
#
# CatalogException: Catalog Error: Table with name books does not exist!
# Did you mean "ol_data_20260321045245.books"?
#
# LINE 1: SELECT * FROM books LIMIT 10
#                       ^

# %%
import duckdb
con = duckdb.connect("open_library.duckdb")

tables = con.execute("SHOW TABLES").fetchdf()
print("Tables dans DuckDB :", tables)

books_df = con.execute("SELECT * FROM books LIMIT 10").fetchdf()
print(books_df)
# Out:
# Tables dans DuckDB : Empty DataFrame
# Columns: [name]
# Index: []
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[17], line 7
#       4 tables = con.execute("SHOW TABLES").fetchdf()
#       5 print("Tables dans DuckDB :", tables)
# ----> 7 books_df = con.execute("SELECT * FROM books LIMIT 10").fetchdf()
#       8 print(books_df)
#
# CatalogException: Catalog Error: Table with name books does not exist!
# Did you mean "ol_data_20260321045245.books"?
#
# LINE 1: SELECT * FROM books LIMIT 10
#                       ^

# %%
con = duckdb.connect("open_library.duckdb")

# Lister tous les schemas
print(con.execute("SHOW SCHEMAS").fetchdf())

# Lister toutes les tables disponibles
print(con.execute("SHOW TABLES").fetchdf())
# Out:
#   database_name             schema_name  current
# 0  open_library                    main     True
# 1  open_library  ol_data_20260321045245    False
# Empty DataFrame
# Columns: [name]
# Index: []

# %%
import duckdb

con = duckdb.connect("open_library.duckdb")

# Voir les tables dans le bon schéma
print("📊 TABLES DANS ol_data_20260321045245:")
tables = con.execute("SHOW TABLES FROM ol_data_20260321045245").fetchdf()
print(tables)
# Out:
# 📊 TABLES DANS ol_data_20260321045245:
#                            name
# 0                    _dlt_loads
# 1           _dlt_pipeline_state
# 2                  _dlt_version
# 3                         books
# 4             books__author_key
# 5            books__author_name
# 6                     books__ia
# 7          books__ia_collection
# 8            books__id_librivox
# 9   books__id_project_gutenberg
# 10    books__id_standard_ebooks
# 11              books__language
# 12            books__series_key
# 13           books__series_name
# 14       books__series_position

# %%
# Lire les livres
books_df = con.execute("SELECT * FROM ol_data_20260321045245.books LIMIT 10").fetchdf()
print("\n📚 Livres:")
print(books_df)

con.close()
# Out:
# 📚 Livres:
#   cover_edition_key   cover_i   ebook_access  edition_count  \
# 0       OL61027601M  15155833     borrowable            397
# 1       OL26378158M  15158660  printdisabled            144
# 2       OL26234270M  10580435     borrowable            279
# 3       OL25683482M  12059372  printdisabled            242
# 4       OL25662116M  15158666  printdisabled            247
# 5               NaN  10716273  printdisabled            177
# 6       OL59041259M  15158664  printdisabled            305
# 7       OL26801911M   8457523       no_ebook             16
# 8               NaN      <NA>       no_ebook              2
# 9       OL28267487M  10195373     borrowable              1
#
#    first_publish_year  has_fulltext                 key lending_edition_s  \
# 0                1997          True     /works/OL82563W       OL38565767M
# 1                2007          True     /works/OL82586W               NaN
# 2                1999          True     /works/OL82536W       OL48101764M
# 3                2000          True     /works/OL82560W               NaN
# 4                2003          True     /works/OL82548W               NaN
# 5                2005          True     /works/OL82565W               NaN
# 6                1998          True     /works/OL82537W               NaN
# 7                1999         False  /works/OL14981609W               NaN
# 8                2001         False  /works/OL21385222W               NaN
# 9                2007          True  /works/OL20874116W       OL28267487M
#
#             lending_identifier_s  public_scan_b  \
# 0  harrypotterylapi0000rowl_q5r6          False
# 1                            NaN          False
# 2                 bdrc-W8LS66814          False
# 3                            NaN          False
# 4                            NaN          False
# 5                            NaN          False
# 6                            NaN          False
# 7                            NaN          False
# 8                            NaN          False
# 9       harrypotterposte0000unse          False
#
#                                        title       _dlt_load_id  \
# 0   Harry Potter and the Philosopher's Stone  1774112013.971483
# 1       Harry Potter and the Deathly Hallows  1774112013.971483
# 2   Harry Potter and the Prisoner of Azkaban  1774112013.971483
# 3        Harry Potter and the Goblet of Fire  1774112013.971483
# 4  Harry Potter and the Order of the Phoenix  1774112013.971483
# 5     Harry Potter and the Half-Blood Prince  1774112013.971483
# 6    Harry Potter and the Chamber of Secrets  1774112013.971483
# 7                  Harry Potter (series) 1-7  1774112013.971483
# 8                               Harry Potter  1774112013.971483
# 9            Harry Potter poster annual 2008  1774112013.971483
#
#           _dlt_id subtitle
# 0  mV8lH3xJSNdo3w     None
# 1  flcaIldttqZXPQ     None
# 2  +usmF0rfDYs6RA     None
# 3  0ODIGJLNUA0Iig     None
# 4  ULCLYSmjqM5lsA     None
# 5  NbqnAbuAK4UJdg     None
# 6  Tz/A8814v8QOQg     None
# 7  ngAk8LU9Uk0RQQ     None
# 8  lUqawGTk0SAwRA     None
# 9  uHd7d3FYQnXjTw     None

# %%
import os
import shutil

# Supprimer les anciennes bases DuckDB
files_to_remove = ["open_library.duckdb", "ol_demo.duckdb"]
for file in files_to_remove:
    if os.path.exists(file):
        os.remove(file)
        print(f"🗑️  Supprimé: {file}")

# Supprimer le cache dlt
if os.path.exists(".dlt"):
    shutil.rmtree(".dlt")
    print("🗑️  Cache .dlt supprimé")

print("✅ Nettoyage terminé")
# Out:
# 🗑️  Supprimé: open_library.duckdb
# ✅ Nettoyage terminé
